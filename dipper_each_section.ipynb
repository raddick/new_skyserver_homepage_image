# %%
import SciServer
from SciServer import SkyServer
from matplotlib import pyplot as plt
print('ok')
# Out:
# ok

# %%
fig, ax = plt.subplots(1,1, figsize=(24,6))
img = SciServer.SkyServer.getJpegImgCutout(ra=159.5, dec=59.25, 
                                           scale=27,  
                                           width=2000, 
                                           height=1000, 
#                                           scale = 120,
#                                           width = 500,
#                                           height = 180,
                                           opt='', 
                                           query='')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.imshow(img)    # show image using pyplot.imshow
#plt.show()
plt.savefig('big_dipper_gray_box.jpg', format='jpg')
print('Done!')
# Out:
# Done!
